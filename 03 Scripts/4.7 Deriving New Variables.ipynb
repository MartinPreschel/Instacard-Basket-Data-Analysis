# %% [markdown]
# # Instructions Exercise: 4.7 Deriving New Variables

# %% [markdown]
# ## Importing important libraries¶

# %%
import pandas as pd  # For DataFrames
import numpy as np  # For numeric calculations
import os  # For file management

# %% [markdown]
# ## Import Pickle file into Pandas

# %%
# Data set path

path = r"/Users/martin/anaconda_projects/11-02-2025 Instacart Basket Analysis"

# %%
# Import of the "ords_prods_merge" data set 

df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 data' , 'Prepared Data' , 'ords_prods_merge.pkl'))

# %%
# Check the result

df_ords_prods_merge.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           0   2539329        1    prior             1                   2
# 2           0   2539329        1    prior             1                   2
# 3           0   2539329        1    prior             1                   2
# 4           0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_po  product_id  add_to_cart_order  reordered  \
# 0                  8      NaN         196                  1          0
# 1                  8      NaN       14084                  2          0
# 2                  8      NaN       12427                  3          0
# 3                  8      NaN       26088                  4          0
# 4                  8      NaN       26405                  5          0
#
# ...

# %% [markdown]
# #

# %%
# Creating a subset by executing the following code:

df = df_ords_prods_merge[:1000000] # Why? To avoid any potential processing issues!

# %%
# Shape check "df_ords_prods_merge" data

df.shape
# Out:
# (1000000, 18)

# %% [markdown]
# ## If-Statements with User-Defined Functions

# %%
# Define the price_label

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply the function 

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/_l/9n60r5ks59sd8bty6knfk2g40000gn/T/ipykernel_6081/2070380426.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# Check the values in the new column

df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    673471
# Low-range product    314116
# High range            12413
# Name: count, dtype: int64

# %%
# Why not check what the most expensive product within the subset is?

df['prices'].max()
# Out:
# 99999.0

# %%
# And the cheapest product within the subset

df['prices'].min()
# Out:
# 1.0

# %% [markdown]
# ## If-Statements with the loc() Function

# %%
# First, let’s create some conditions!

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Check the values in the new column

df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    673471
# Low-range product    314116
# High range            12413
# Name: count, dtype: int64

# %% [markdown]
# ### Repeating the process—this time, on your entire dataframe:

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Check the values in the new column

df_ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: count, dtype: int64

# %% [markdown]
# ## If-Statements with For-Loops

# %%
#To start, you need to know on which day most orders take place

df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: count, dtype: int64

# %%
# Create a new column, “busiest day,” that will contain one of three different values: “Busiest day,” “Least busy,” and “Regularly busy.

result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# The first step is to create an empty list, result. This will act as the empty shell, into which you can place the results from your loop

result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#
df_ords_prods_merge['Busiest day'] = result

# %%
#
df_ords_prods_merge['Busiest day'].value_counts(dropna = False)
# Out:
# Busiest day
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: count, dtype: int64

# %% [markdown]
# #

# %% [markdown]
# # Task 4.7 Deriving New Variables

# %% [markdown]
# ## Task 2)

# %%
# Create column busiest_days from "orders_day_of_week" to identify two busiest days (0, 1), slowest days (4, 3), 
# or regularly busy (all other days)

result_2 = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0 or value == 1:
    result_2.append("Busiest day")
  elif value == 3 or value == 4:
    result_2.append("Slowest days")
  else:
    result_2.append("Regularly busy")

# %%
# Next I create an empty list, result_2. This will act as the empty shell, into which I can place the results from your loop I just created.

result_2
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Slowest days',
#  'Slowest days',
# ...

# %%
# Create new 'busiest_days' column in df_ords_prods_merge to view results in context

df_ords_prods_merge['Busiest days'] = result_2

# %% [markdown]
# ## Task 3)

# %%
# Showing the results

df_ords_prods_merge['Busiest day'].value_counts(dropna = False)
# Out:
# Busiest day
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: count, dtype: int64

# %%
## Observations on 'Busiest days' Column

# - The classification includes three expected categories: 'Busiest day', 'Regularly busy', and 'Least busy'.
# - The majority of orders fall into 'Regularly busy' (22437387), which makes sense given that most days should have an average order volume.
# - 'Busiest day' (6209632) and 'Least busy' (3787193) show significantly different volumes, indicating a clear distinction between peak and slow days.
# - No NaN values are present, meaning all orders have been classified.
# - Further validation might be needed by cross-checking these labels with the actual `order_dow` values to confirm correctness.

# %% [markdown]
# ## Task 4)

# %%
#To start, I need to know on which hour most orders take place by making a order frequency analysis

df_ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: count, dtype: int64

# %%
# Creating busiest_period_of_day column to categorize order times

result_3 = []

# Defining categories based on order frequency analysis

most_orders = [10, 11, 12, 13, 14, 15, 16] # Peak order hours
average_orders = [7, 8, 9, 17, 18, 19, 20, 21, 22, 23] # Moderate order hours
fewer_orders = [0, 1, 2, 3, 4, 5, 6] # Low activity hours

for value in df_ords_prods_merge["order_hour_of_day"]:
  if value in most_orders:
    result_3.append("Most orders")
  elif value in average_orders:
    result_3.append("Average orders")
  else:
    result_3.append("Fewest orders")

# %%
# Creating the new column in the DataFrame

df_ords_prods_merge["busiest_period_of_day"] = result_3

# %% [markdown]
# ## Task 5)

# %%
# Checking the result

df_ords_prods_merge["busiest_period_of_day"].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# Most orders       18680601
# Average orders    12866025
# Fewest orders       887586
# Name: count, dtype: int64

# %%
## Observations on 'busiest_period_of_day' Column

# - The classification includes three expected categories: 'Most orders', 'Average orders', and 'Fewest orders'.
# - The majority of orders (18,680,601) occur during the "Most orders" period, suggesting that Instacart experiences peak traffic during specific hours.
# - The "Average orders" period still has a high number of orders (12,866,025), indicating a steady demand throughout the day.
# - The "Fewest orders" period has significantly fewer orders (887,586), likely corresponding to late-night or early-morning hours when fewer people are shopping.
# - These insights could help Instacart optimize server performance, schedule maintenance during low-traffic hours, and manage resources more efficiently.

# %% [markdown]
# ## Task 7)

# %%
# Export dataframe as Pickle

df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_2.pkl'))
